# %%
import pandas as pd

df = pd.read_csv('/Users/giovanni-lunetta/uconn_masters/s2/stat_5125/Final Project/all_games_df.csv')
df_old = pd.read_csv('/Users/giovanni-lunetta/uconn_masters/s2/stat_5125/Final Project/regular_season_2002_2020.csv')

df.head()
# Out:
#    ...1           Year_Week           Round  Day        Date  Time (ET)  \
# 0     1  Year_2002_Playoffs   AFC Wild Card  Sat  2003-01-04  4H 39M 0S
# 1     2  Year_2002_Playoffs   NFC Wild Card  Sat  2003-01-04   8H 8M 0S
# 2     3  Year_2002_Playoffs   AFC Wild Card  Sun  2003-01-05   1H 1M 0S
# 3     4  Year_2002_Playoffs   NFC Wild Card  Sun  2003-01-05  4H 47M 0S
# 4     5  Year_2002_Playoffs  AFC Divisional  Sat  2003-01-11  4H 36M 0S
#
#   Favorite_Home             Favorite             Underdog  Favorite_Win  \
# 0             H        New York Jets   Indianapolis Colts             1
# 1             H    Green Bay Packers      Atlanta Falcons             0
# 2             H  Pittsburgh Steelers     Cleveland Browns             1
# 3             H  San Francisco 49ers      New York Giants             1
# 4             H     Tennessee Titans  Pittsburgh Steelers             1
#
#    Overtime  Favorite_Score  Underdog_Score  Total_Points Over_Under_Result  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5929 entries, 0 to 5928
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ...1               5929 non-null   int64
#  1   Year_Week          5929 non-null   object
#  2   Round              250 non-null    object
#  3   Day                5929 non-null   object
#  4   Date               5929 non-null   object
#  5   Time (ET)          5929 non-null   object
#  6   Favorite_Home      5929 non-null   object
#  7   Favorite           5929 non-null   object
#  8   Underdog           5929 non-null   object
#  9   Favorite_Win       5929 non-null   int64
#  10  Overtime           5929 non-null   int64
#  11  Favorite_Score     5929 non-null   int64
#  12  Underdog_Score     5929 non-null   int64
#  13  Total_Points       5929 non-null   int64
#  14  Over_Under_Result  5929 non-null   object
#  15  Betting_Line       5929 non-null   float64
# ...

# %%
# create a dataframe where spread is null

df_null = df[df['Spread_Value'].isna()]

df_null
# Out:
#       ...1          Year_Week Round  Day        Date  Time (ET) Favorite_Home  \
# 252      3   Year_2002_Week_1   NaN  Sun  2002-09-08   1H 4M 0S             H
# 266     17   Year_2002_Week_2   NaN  Sun  2002-09-15   1H 0M 0S             H
# 556    307   Year_2003_Week_4   NaN  Sun  2003-09-28   1H 3M 0S             H
# 595    346   Year_2003_Week_7   NaN  Sun  2003-10-19   1H 2M 0S             H
# 643    394  Year_2003_Week_10   NaN  Sun  2003-11-09   1H 3M 0S             H
# 834    585   Year_2004_Week_5   NaN  Sun  2004-10-10  8H 36M 0S             H
# 881    632   Year_2004_Week_9   NaN  Sun  2004-11-07   1H 2M 0S             H
# 932    683  Year_2004_Week_12   NaN  Sun  2004-11-28  4H 15M 0S             H
# 995    746  Year_2004_Week_16   NaN  Sun  2004-12-26   4H 5M 0S             H
# 1095   846   Year_2005_Week_6   NaN  Sun  2005-10-16   1H 2M 0S             H
# 1102   853   Year_2005_Week_6   NaN  Sun  2005-10-16  4H 15M 0S             H
# ...

# %%
df_old.head()
# Out:
#    Unnamed: 0            source  Day         Date Time (ET) ...4  \
# 0           1  Year_2002_Week_1  Thu  Sep 5, 2002      8:38  NaN
# 1           2  Year_2002_Week_1  Sun  Sep 8, 2002      1:04  NaN
# 2           3  Year_2002_Week_1  Sun  Sep 8, 2002      1:04    @
# 3           4  Year_2002_Week_1  Sun  Sep 8, 2002      1:04    @
# 4           5  Year_2002_Week_1  Sun  Sep 8, 2002      1:04    @
#
#               Favorite         Score  Spread ...8            Underdog  \
# 0  San Francisco 49ers       W 16-13    L -4    @     New York Giants
# 1        New York Jets  W 37-31 (OT)    W -3    @       Buffalo Bills
# 2    Carolina Panthers        W 10-7    W PK  NaN    Baltimore Ravens
# 3        Chicago Bears       W 27-23  L -4.5  NaN   Minnesota Vikings
# 4   Cincinnati Bengals        L 6-34    L -3  NaN  San Diego Chargers
#
#   Over/Under  Notes ...12
# 0       U 39  Notes   NaN
# 1       O 43    NaN   NaN
# 2       U 33    NaN   NaN
# 3       O 41    NaN   NaN
# ...

# %%
df_old['Score'].sample(30)
# Out:
# 1632         W 28-21
# 3108         W 23-21
# 1511         L 23-38
# 4447         W 27-17
# 4654         L 30-37
# 2622         L 18-34
# 784           W 10-3
# 2132         W 28-20
# 3004         W 17-10
# 2184         W 31-16
# 3487         W 20-13
# 4629         W 31-28
# 459           W 17-6
# 2540          W 20-7
# 4070         W 37-16
# 2531         W 27-24
# 3824         L 10-27
# 719          W 49-38
# 4653         W 38-31
# 3862          W 26-9
# 3636         W 27-20
# 3548         W 30-14
# 851          W 27-17
# 2820         W 34-24
# 4333         W 31-28
# 4304         L 28-29
# 473     W 23-20 (OT)
# 2457         L 21-27
# 3576         L 23-34
# 3557         L 12-18
# Name: Score, dtype: object
